# %% [markdown]
# <a href="https://colab.research.google.com/github/Shojaiaa/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Title: (Prediction of Product Sales).

# %% [markdown]
# - Author : Ali Nedal

# %% [markdown]
# ## Project Overview

# %% [markdown]
# ## Load and Inspect Data

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Feature Inspection

# %%
# Import Pandas and load the dataset
import pandas as pd
sales_predictions = '/content/drive/MyDrive/AXSOSACADEMY/AXSOSACADEMY/01-Fundamentals/Week03/sales_predictions_2023.csv'
df = pd.read_csv(sales_predictions)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# Preview the first five rows of the dataset
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Display information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# How many rows and columns?
df.shape
# Out:
# (8523, 12)

# %%
# What are the datatypes of each variable?
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Are there duplicates? If so, drop any duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Identify missing values
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Address the missing values by using a placeholder value
df['Item_Weight'] = df['Item_Weight'].fillna(-1)
df['Outlet_Size'] = df['Outlet_Size'].fillna('MISSING')

# %%
# Confirm that there are no missing values after addressing them
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
# Find any inconsistent categories of data
string_columns = df.select_dtypes(include= ['object']).columns
for col in string_columns:
    print(col)
    print(df[col].value_counts())
    print('\n')
# Out:
# Item_Identifier
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
#
#
# Item_Fat_Content
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
#
# Item_Type
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64
#
#
# Outlet_Identifier
# ...

# %%
# Fix inconsistent values in Item_Fat_Content
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({
    'LF': 'Low Fat',
    'low fat': 'Low Fat',
    'reg': 'Regular',
})

# %%
# Check the values after fixing inconsistencies
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
# For any numerical columns, obtain the summary statistics of each (min, max, mean)
df.select_dtypes(include=['number']).agg(['min', 'max', 'mean'])
# Out:
#       Item_Weight  Item_Visibility    Item_MRP  Outlet_Establishment_Year  \
# min     -1.000000         0.000000   31.290000                1985.000000
# max     21.350000         0.328391  266.888400                2009.000000
# mean    10.478936         0.066132  140.992782                1997.831867
#
#       Item_Outlet_Sales
# min           33.290000
# max        13086.964800
# mean        2181.288914

# %%
# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Check the data types for all columns in the table
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Histogram to view the distribution of Item Outlet Sales
plt.figure(figsize=(8, 6))

sns.histplot(data=df, x= 'Item_Outlet_Sales', bins= 'auto')
plt.title('Distribution of Item Outlet Sales')
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('count')

plt.show()

# %% [markdown]
# # The graph shows that the sales outlet brings in a large number of products that generate medium to low sales and a very small number of high sales.

# %%
# Boxplot: Item Outlet Sales by Outlet Type
plt.figure(figsize=(8, 6))

sns.boxplot(data=df,x='Outlet_Type', y='Item_Outlet_Sales')
plt.title('Item_Outlet_Sales by Outlet_Type')
plt.xlabel('Outlet_Type')
plt.ylabel('Item_Outlet_Sales')

plt.show()

# %% [markdown]
# # Supermarket Type3 shows the highest median sales compared to other outlet types, suggesting that outlet type is an important factor in sales performance.

# %%
# Countplot: Frequency of Outlet Types
plt.figure(figsize=(8, 6))

sns.countplot(data=df,x='Outlet_Type')
plt.title('Count of Outlet Types')
plt.xlabel('Outlet_Type')
plt.ylabel('count')

plt.show()

# %% [markdown]
# # Although Supermarket Type1 appears most frequently in the dataset, the previous boxplot showed that Supermarket Type3 has higher sales, suggesting that outlet frequency does not necessarily reflect sales performance.

# %%
# Get correlations
corr= df.corr(numeric_only= True)
corr.round(2)
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                       1.00            -0.08      0.02
# Item_Visibility                  -0.08             1.00     -0.00
# Item_MRP                          0.02            -0.00      1.00
# Outlet_Establishment_Year         0.54            -0.07      0.01
# Item_Outlet_Sales                -0.06            -0.13      0.57
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                     0.54              -0.06
# Item_Visibility                                -0.07              -0.13
# Item_MRP                                        0.01               0.57
# Outlet_Establishment_Year                       1.00              -0.05
# Item_Outlet_Sales                              -0.05               1.00

# %%
# Make heatmap of correlations
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(corr, cmap = 'coolwarm', annot = True, ax=ax);
plt.title('Correlation Heatmap of Numerical Features')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Numerical Features')

# %% [markdown]
# # The heatmap shows that Item_MRP has the strongest positive correlation with Item_Outlet_Sales. Combined with the previous boxplot, this suggests that both product pricing and outlet type may be important factors in sales performance.

# %%
plt.figure(figsize=(12, 7))

# Product ranking based on highest average sales
ordered_items = df.groupby('Item_Type')['Item_Outlet_Sales'].mean().sort_values(ascending=False).index

# Sales drawing
sns.barplot(data=df, x='Item_Outlet_Sales', y='Item_Type', order=ordered_items, errorbar=None)

plt.title('Average Sales by Item Type (Ordered)')
plt.xlabel('Average Sales')
plt.ylabel('Item Type')
plt.show()

# %% [markdown]
# # The graph shows the average sales for products from highest to lowest.

# %%
plt.figure(figsize=(10, 6))

# Charting the relationship between price and sales according to store type
sns.scatterplot(data=df, x='Item_MRP', y='Item_Outlet_Sales', hue='Outlet_Type', alpha=0.6, palette='Dark2')

plt.title('Impact of Item MRP on Outlet Sales Across Store Types')
plt.xlabel('Item Maximum Retail Price (MRP)')
plt.ylabel('Item Outlet Sales')

plt.show()

# %% [markdown]
# # The chart shows that higher item prices are usually linked with higher sales. Grocery Stores seem to have the lowest sales, while Supermarket Type3 performs better than the other store types.

# %%
# Replace placeholders with null values
df['Item_Weight'] = df['Item_Weight'].replace(-1, np.nan)
df['Outlet_Size'] = df['Outlet_Size'].replace('MISSING', np.nan)
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Create a feature summary table
feature_summary = pd.DataFrame({
    'Data type': df.dtypes,
    'Null_count': df.isna().sum(),
    'Null percentage': (df.isna().sum()/len(df)*100).round(2),
    'Unique Values': df.nunique()
})

feature_summary
# Out:
#                           Data type  Null_count  Null percentage  \
# Item_Identifier              object           0             0.00
# Item_Weight                 float64        1463            17.17
# Item_Fat_Content             object           0             0.00
# Item_Visibility             float64           0             0.00
# Item_Type                    object           0             0.00
# Item_MRP                    float64           0             0.00
# Outlet_Identifier            object           0             0.00
# Outlet_Establishment_Year     int64           0             0.00
# Outlet_Size                  object        2410            28.28
# Outlet_Location_Type         object           0             0.00
# Outlet_Type                  object           0             0.00
# Item_Outlet_Sales           float64           0             0.00
#
#                            Unique Values
# Item_Identifier                     1559
# ...

# %% [markdown]
# # Feature: Item_Identifier
#
# **Definition:** Unique product ID.

# %%
# Univariate visualization for Item_Identifier
top_items = df['Item_Identifier'].value_counts().head(20)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_items.index, y=top_items.values)

plt.title('Top 20 Most Frequent Item Identifiers')
plt.xlabel('Item Identifier')
plt.ylabel('Count')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# **About this property:**
#
# - This property is classificatory.
#
# - It has no missing values.
#
# - It is not static, as it contains many different product identifiers.
#
# - It has high density, containing 1559 unique values.
#
# - This property can be determined before recording sales figures.
#
# - I do not recommend using this property directly in the form, as it is merely an identifier and may not be useful for predicting sales of new products.

# %%
# Multivariate visualization: Item_Identifier vs Item_Outlet_Sales
top_items_ids = df['Item_Identifier'].value_counts().head(20).index
df_top_items = df[df['Item_Identifier'].isin(top_items_ids)]

plt.figure(figsize=(12, 6))
sns.barplot(data= df_top_items, x= 'Item_Identifier',y='Item_Outlet_Sales', errorbar=None )

plt.title('Average Item Outlet Sales for Top 20 Most Frequent Item Identifiers')
plt.xlabel('Item Identifier')
plt.ylabel('Average Item Outlet Sales')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - I do not expect this feature to be a strong predictor by itself because it is only a product ID.
# - The chart shows that average sales are different between some item IDs, but because there are too many unique IDs, this feature may not work well directly in a future model.

# %% [markdown]
# # Feature: Item_Weight
#
# **Definition:** Weight of the product.

# %%
# Univariate visualization for Item_Weight
plt.figure(figsize=(8, 6))

sns.histplot(data=df, x='Item_Weight', bins=30)

plt.title('Distribution of Item Weight')
plt.xlabel('Item Weight')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is numeric
#
# - It has 1,463 missing values, which is 17.17% of the dataset.
# - I would impute the missing values using the median because this is a numeric feature and the median is less affected by extreme values.
# - It is not constant because it has many different weight values.
# - It has 415 unique values, More than 10 is considered high
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because product weight may be related to product type and customer purchasing behavior.

# %%
# Multivariate visualization: Item_Weight vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='Item_Weight', y='Item_Outlet_Sales', alpha=0.5)

plt.title('Item Weight vs Item Outlet Sales')
plt.xlabel('Item Weight')
plt.ylabel('Item_Outlet_Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - The relationship between product weight and sales appears to be weak.
# - From the scatterplot, there does not appear to be a strong clear pattern between Item_Weight and Item_Outlet_Sales, so this feature may not be a strong predictor by itself.

# %% [markdown]
# # Feature: Item_Fat_Content
#
# **Definition:** Whether the product is low fat or regular.

# %%
# Univariate visualization for Item_Fat_Content
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='Item_Fat_Content')

plt.title('Count of Item Fat Content')
plt.xlabel('Item_Fat_Content')
plt.ylabel('count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is categorical
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has more than one category.
# - It has low cardinality with 2 unique values.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because product fat content may help explain customer preferences and sales.

# %%
# Multivariate visualization: Item_Fat_Content vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='Item_Fat_Content', y='Item_Outlet_Sales')

plt.title('Item Outlet Sales by Item Fat Content')
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item Outlet Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - I would expect this feature to have some relationship with sales because customers may prefer certain product types.
# - From the boxplot, the sales distributions for Low Fat and Regular items look fairly similar, so this feature may not be a strong predictor by itself.

# %% [markdown]
# ## Feature: Item_Visibility
#
# **Definition:** The percentage of total display area of all products in a store allocated to the particular product.

# %%
# Univariate visualization for Item_Visibility
plt.figure(figsize=(8, 6))

sns.histplot(data=df, x='Item_Visibility', bins=30)

plt.title('Distribution of Item Visibility')
plt.xlabel('Item_Visibility')
plt.ylabel('count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is numeric
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has many different values.
# - It has 7,880 unique values
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because product visibility in the outlet may affect customer attention and sales.

# %%
# Multivariate visualization: Item_Visibility vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='Item_Visibility', y='Item_Outlet_Sales', alpha=0.5)

plt.title('Item_Visibility vs Item Outlet Sales')
plt.xlabel('Item_Visibility')
plt.ylabel('Item_Outlet_Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - I expected Item_Visibility to have some relationship with sales because products with more display visibility may attract more customers.
# - From the scatterplot, there is no strong clear pattern between Item_Visibility and Item_Outlet_Sales.
# - This feature may still be useful, but it does not appear to be a strong predictor by itself.

# %% [markdown]
# ## Feature: Item_Type
#
# **Definition:** The category/type of the product.

# %%
# Univariate visualization for Item_Type
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='Item_Type')

plt.title('Count Item_Type')
plt.xlabel('Item_Type')
plt.ylabel('count')
plt.xticks(rotation=60)

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is categorical
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has several product categories.
# - It has high cardinality with 16 unique values, which is greater than 10.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because the type of product may affect customer demand and sales.

# %%
# Multivariate visualization: Item_Type vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='Item_Type', y='Item_Outlet_Sales')

plt.title('Item Outlet Sales by Item Type')
plt.xlabel('Item_Type')
plt.ylabel('Item_Outlet_Sales')
plt.xticks(rotation=60)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect Item_Type to be a predictor because some product categories may be more popular than others.
# - From the boxplot, sales vary across item types, but the differences are not very large for most categories, so this feature may be useful but not a very strong predictor by itself.

# %% [markdown]
# ## Feature: Item_MRP
#
# **Definition:** Maximum Retail Price of the product.

# %%
# Univariate visualization for Item_MRP
plt.figure(figsize=(8, 6))

sns.histplot(data=df, x='Item_MRP')

plt.title('Distribution of Item_MRP')
plt.xlabel('Item_MRP')
plt.ylabel('count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is numeric
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has many different price values.
# - It has 5,938 unique values, but cardinality is mainly considered for categorical features.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because product price is directly related to sales and customer purchasing decisions.

# %%
# Multivariate visualization: Item_MRP vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='Item_MRP', y='Item_Outlet_Sales', alpha=0.5)

plt.title('Item_MRP vs Item Outlet Sales')
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect Item_MRP to be a predictor because product price can affect total sales value.
# - From the scatterplot, Item_MRP appears to have a positive relationship with Item_Outlet_Sales, so this feature looks useful for predicting sales.

# %% [markdown]
# ## Feature: Outlet_Identifier
#
# **Definition:** Unique store ID.

# %%
# Univariate visualization for Outlet_Identifie
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='Outlet_Identifier')

plt.title('Count Outlet_Identifier')
plt.xlabel('Outlet_Identifier')
plt.ylabel('count')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is categorical
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has more than one outlet ID.
# - It has 10 unique values, so it is not considered high cardinality based on the >10 rule.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because different outlets may have different sales results.

# %%
# Multivariate visualization: Outlet_Identifier vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='Outlet_Identifier', y='Item_Outlet_Sales')

plt.title('Item_Outlet_Sales by Outlet_Identifier')
plt.xlabel('Outlet_Identifier')
plt.ylabel('Item Outlet Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect Outlet_Identifier to be related to sales because each store may have different performance, location, size, and customer traffic.
# - From the boxplot, sales appear to vary between outlets, so this feature may be useful for predicting sales in this dataset.

# %% [markdown]
# ## Feature: Outlet_Establishment_Year
#
# **Definition:** The year in which the outlet was established.

# %%
# Univariate visualization for Outlet_Establishment_Year
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x='Outlet_Establishment_Year')

plt.title('Count of Outlet Establishment Years')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is numeric.
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has more than one establishment year.
# - It has 9 unique values, so it is not considered high cardinality.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because older or newer outlets may have different sales performance.

# %%
# Multivariate visualization: Outlet_Establishment_Year vs Item_Outlet_Sales
plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x='Outlet_Establishment_Year', y='Item_Outlet_Sales')

plt.title('Item Outlet Sales by Outlet Establishment Year')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect this feature to have some relationship with sales because older outlets may have more established customers.
# - From the boxplot, sales appear to vary across establishment years, so this feature may be useful for predicting sales.

# %% [markdown]
# ## Feature: Outlet_Size
#
# **Definition:** The size of the outlet in terms of ground area covered.

# %%
# Univariate visualization for Outlet_Size
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='Outlet_Size', order=['Small', 'Medium', 'High'])

plt.title('Count of Outlet Sizes')
plt.xlabel('Outlet Size')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is categorical ordinal because outlet size has a clear order: Small, Medium, and High.
# - It has 2,410 missing values, which is 28.28% of the dataset.
# - I would impute the missing values using the most frequent category because this is a categorical feature.
# - It is not constant because it has more than one outlet size.
# - It has low cardinality with 3 unique values.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because outlet size may affect sales performance.

# %%
# Multivariate visualization: Outlet_Size vs Item_Outlet_Sales
plt.figure(figsize=(7, 5))

sns.boxplot(data=df, x='Outlet_Size', y='Item_Outlet_Sales', order=['Small', 'Medium', 'High'])

plt.title('Item Outlet Sales by Outlet Size')
plt.xlabel('Outlet Size')
plt.ylabel('Item Outlet Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect Outlet_Size to be a predictor because larger outlets may have more space, more products, and more customer traffic.
# - From the boxplot, sales appear to vary across outlet sizes, so this feature may be useful for predicting sales.

# %% [markdown]
# ## Feature: Outlet_Location_Type
#
# **Definition:** The type of location where the outlet is located.

# %%
# Univariate visualization for Outlet_Location_Type
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='Outlet_Location_Type', order=['Tier 1', 'Tier 2', 'Tier 3'])

plt.title('Count of Outlet Location Types')
plt.xlabel('Outlet Location Type')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is categorical.
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has more than one location type.
# - It has low cardinality with 3 unique values.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because outlet location may affect customer traffic and sales.

# %%
# Multivariate visualization: Outlet_Location_Type vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='Outlet_Location_Type', y='Item_Outlet_Sales', order=['Tier 1', 'Tier 2', 'Tier 3'])

plt.title('Item Outlet Sales by Outlet Location Type')
plt.xlabel('Outlet Location Type')
plt.ylabel('Item Outlet Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect Outlet_Location_Type to be a predictor because store location can affect customer traffic and sales.
# - From the boxplot, sales appear to vary between location types. Tier 2 and Tier 3 seem to have higher sales than Tier 1, so this feature may be useful for predicting sales.

# %% [markdown]
# ## Feature: Outlet_Type
#
# **Definition:** The type of store/outlet where the product is sold, such as grocery store or supermarket type.

# %%
# Univariate visualization for Outlet_Type
plt.figure(figsize=(8, 6))

sns.countplot(data=df, x='Outlet_Type')

plt.title('Count of Outlet Types')
plt.xlabel('Outlet Type')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **About this feature:**
#
# - This feature is categorical.
# - It has 0 missing values, so I do not need to handle null values here.
# - It is not constant because it has more than one outlet type.
# - It has low cardinality with 4 unique values.
# - This feature would be known before the sales value is recorded.
# - I would keep this feature because different outlet types may have different sales results.

# %%
# Multivariate visualization: Outlet_Type vs Item_Outlet_Sales
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='Outlet_Type', y='Item_Outlet_Sales')

plt.title('Item Outlet Sales by Outlet Type')
plt.xlabel('Outlet Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Relationship with sales:**
#
# - Based on business understanding, I would expect Outlet_Type to be a predictor because grocery stores and supermarkets may have different sales patterns.
# - From the boxplot, sales clearly vary between outlet types. Supermarket Type3 has the highest sales distribution, while Grocery Store has the lowest, so this feature appears to be a useful predictor of sales.

# %%
# Load fresh original dataset
sales_predictions = '/content/drive/MyDrive/AXSOSACADEMY/AXSOSACADEMY/01-Fundamentals/Week03/sales_predictions_2023.csv'
df = pd.read_csv(sales_predictions)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Fix inconsistent categorical values
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    print(f'column : {col}')
    print(df[col].value_counts(dropna=False))
    print('\n')
# Out:
# column : Item_Identifier
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
#
#
# column : Item_Fat_Content
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
#
# column : Item_Type
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64
#
#
# ...

# %%
# Fix inconsistent categories in Item_Fat_Content
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({
    'LF': 'Low Fat',
    'low fat': 'Low Fat',
    'reg': 'Regular'
})

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
# Define features (X) and target (y)
X = df.drop(columns=['Item_Outlet_Sales', 'Item_Identifier'])
y = df['Item_Outlet_Sales']

# %%
# Check X and y
print("X shape:", X.shape)
print("y shape:", y.shape)
X.head()
# Out:
# X shape: (8523, 10)
# y shape: (8523,)
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998         NaN
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Check the percentages after train-test split
train_percent = len(X_train) / len(X) * 100
test_percent = len(X_test) / len(X) * 100

train_percent, test_percent
# Out:
# (74.99706676053033, 25.00293323946967)

# %%
# Select numeric and categorical columns
num_cols = X_train.select_dtypes(include='number').columns
cat_cols = X_train.select_dtypes(include='object').columns

# %%
# Import preprocessing tools
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

# %%
num_pipeline = make_pipeline(SimpleImputer(strategy='median'))

cat_pipeline = make_pipeline(
    SimpleImputer(strategy='most_frequent'),
    OneHotEncoder(handle_unknown='ignore')
)

# %%
# Create preprocessing object
preprocessor = ColumnTransformer([
    ('numeric', num_pipeline, num_cols),
    ('categorical', cat_pipeline, cat_cols)
])

# %%
# Fit the preprocessor on training data only
preprocessor.fit(X_train)

# Transform training and testing data
X_train_processed = preprocessor.transform(X_train)
X_test_processed = preprocessor.transform(X_test)
